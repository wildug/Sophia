# %%
import tueplots
from tueplots import bundles
from tueplots.constants.color import rgb
from tueplots import fonts, fontsizes
import pandas as pd




settings = bundles.beamer_moml(rel_width=2, rel_height=2)
factor = 2
settings['font.size'] = 9 * factor
settings['axes.labelsize'] = 9* factor
settings['legend.fontsize'] = 7* factor
settings['xtick.labelsize'] = 7* factor
settings['ytick.labelsize'] = 7* factor
settings['axes.titlesize'] = 9* factor
plt.rcParams.update(settings)
# fig, ax = plt.subplots(1)

# ax.plot([1, 2, 3], [1, 2, 3])

# %%
data = pd.read_csv("results/sophia_adam_steps.csv")
data
# Out:
#      Step  gpt2-small-adamW-10k - val/loss  \
# 0       0                        10.862690
# 1    1000                         4.506587
# 2    2000                         4.155799
# 3    3000                         4.085250
# 4    4000                         4.011796
# 5    5000                         3.923043
# 6    6000                         3.854426
# 7    7000                         3.755532
# 8    8000                         3.698455
# 9    9000                         3.623896
# 10  10000                         3.621266
#
#     gpt2-small-adamW-10k - val/loss__MIN  \
# 0                              10.862690
# 1                               4.506587
# 2                               4.155799
# 3                               4.085250
# 4                               4.011796
# 5                               3.923043
# 6                               3.854426
# 7                               3.755532
# 8                               3.698455
# ...

# %%
adam = data["gpt2-small-adamW-10k - val/loss"]
sophia = data["gpt2-small-sophiag-10k - val/loss"]
steps = data["Step"]

fig, ax = plt.subplots(1)

ax.plot(steps, adam, label="AdamW")
ax.plot(steps, sophia, label="SophiaG")
ax.set_xlabel("Steps")
ax.set_ylabel("Validation Loss")
ax.legend()
plt.savefig("results/steps_adam_sophia.pdf")
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# ...

# %%
import numpy as np

fig, ax = plt.subplots(1)

time_adam = 5*60+ 21
time_sophia = 6*60+48
minutes_adam = np.linspace(0, time_adam, 11)
minutes_sophia = np.linspace(0, time_sophia, 11)

ax.plot( minutes_adam, adam, label="AdamW")
ax.plot(minutes_sophia, sophia, label="SophiaG")
ax.set_xlabel("Minutes")
ax.set_ylabel("Validation Loss")
ax.legend()
plt.savefig("results/time_adam_sophia.pdf")
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# ...

# %%
import numpy as np

pandas = pd.read_csv("results/long_adam_run.csv")
adam = pandas["gpt2-small-adamW-10k - val/loss"]

fig, ax = plt.subplots(1)

time_adam_long = 6*60+ 31
time_sophia = 6*60+48
minutes_adam = np.linspace(0, time_adam_long, 13)
minutes_sophia = np.linspace(0, time_sophia, 11)

ax.plot( minutes_adam, adam, label="AdamW")
ax.plot(minutes_sophia, sophia, label="SophiaG")
ax.set_xlabel("Minutes")
ax.set_ylabel("Validation Loss")
ax.legend()

plt.savefig("results/time_adam_long_sophia.pdf")
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# ...
